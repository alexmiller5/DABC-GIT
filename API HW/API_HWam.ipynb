# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data_cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 606

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

# %%
# Create empty lists to append the API data into lists
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# Start the call counter
record = 1

# Log file print statement
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

#Loop through the cities in the city list
for city in cities:
    # Try statement to append calls where value is found
    # Not all calls return data as OpenWeatherMap will not have have records in all the cities generated by CityPy module

    try:
        response = requests.get(f"{url}&q={city}").json()
        city_name.append(response["name"]) 
        cloudiness.append(response["clouds"]["all"]) 
        country.append(response["sys"]["country"]) 
        date.append(response["dt"]) 
        humidity.append(response["main"]["humidity"]) 
        max_temp.append(response["main"]["temp_max"]) 
        lat.append(response["coord"]["lat"]) 
        lng.append(response["coord"]["lon"]) 
        wind_speed.append(response["wind"]["speed"]) 
        city_record = response["name"] 
        print(f"Processing Record {record} | {city_record}")
        print(f"{url}&q={city}")

# Increase counter by one
        record= record + 1
# Wait a second in loop to not over exceed rate limit of A
        time.sleep(1.01)
# If no record found "skip" to next call
    except:
        print("City not found. Skipping...")
    continue
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 | Mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=mataura
# Processing Record 2 | Karibib
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=karibib
# Processing Record 3 | Vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=vaini
# Processing Record 4 | Jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=jamestown
# Processing Record 5 | San Miguel de Cauri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=san miguel de cauri
# Processing Record 6 | Altay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=altay
# Processing Record 7 | Weston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=weston
# Processing Record 8 | Vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=vardo
# Processing Record 9 | Pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=pisco
# Processing Record 10 | Airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=airai
# City not found. Skipping...
# Processing Record 11 | Busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=busselton
# Processing Record 12 | Punta Arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=punta arenas
# Processing Record 13 | Palmer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=palmer
# Processing Record 14 | Nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=nome
# Processing Record 15 | Kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=kahului
# Processing Record 16 | Hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=hithadhoo
# Processing Record 17 | Bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=bluff
# Processing Record 18 | Harbin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=harbin
# Processing Record 19 | Nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=nikolskoye
# Processing Record 20 | Ugoofaaru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=ugoofaaru
# Processing Record 21 | Sabha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=sabha
# Processing Record 22 | Kalmunai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=kalmunai
# Processing Record 23 | Cape Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=cape town
# Processing Record 24 | Albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=albany
# Processing Record 25 | Sovetskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=sovetskoye
# Processing Record 26 | Bogorodskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=bogorodskoye
# Processing Record 27 | Hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=hermanus
# Processing Record 28 | Padang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=padang
# Processing Record 29 | Klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=klaksvik
# Processing Record 30 | Kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=kaitangata
# Processing Record 31 | Rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=rikitea
# City not found. Skipping...
# Processing Record 32 | Kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=kodiak
# Processing Record 33 | Thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=thompson
# Processing Record 34 | Provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=provideniya
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 35 | Zheleznogorsk-Ilimskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=zheleznogorsk-ilimskiy
# Processing Record 36 | Sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=sitka
# Processing Record 37 | Ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=ushuaia
# Processing Record 38 | San Cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=san cristobal
# Processing Record 39 | Hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=hilo
# Processing Record 40 | Kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=kruisfontein
# Processing Record 41 | Kachug
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=kachug
# Processing Record 42 | Port Alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=port alfred
# Processing Record 43 | Marietta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=marietta
# Processing Record 44 | Khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=khatanga
# Processing Record 45 | Rozkishne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=rozkishne
# Processing Record 46 | Giaveno
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=giaveno
# Processing Record 47 | Pleasanton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=pleasanton
# Processing Record 48 | New Norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=new norfolk
# Processing Record 49 | Nishihara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=nishihara
# Processing Record 50 | Atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=atuona
# Processing Record 51 | Lakes Entrance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=lakes entrance
# Processing Record 52 | Victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=victoria
# Processing Record 53 | Norman Wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=norman wells
# Processing Record 54 | Hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=hobart
# Processing Record 55 | Tigil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=tigil
# Processing Record 56 | Coihaique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=coihaique
# City not found. Skipping...
# Processing Record 57 | Teahupoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=teahupoo
# Processing Record 58 | Gigmoto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=gigmoto
# Processing Record 59 | Takaka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=takaka
# Processing Record 60 | Ribeira Grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=ribeira grande
# Processing Record 61 | Avera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=avera
# Processing Record 62 | Quatre Cocos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=quatre cocos
# Processing Record 63 | Upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=upernavik
# Processing Record 64 | Iskateley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=iskateley
# Processing Record 65 | Bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=bredasdorp
# City not found. Skipping...
# Processing Record 66 | Vanimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=vanimo
# Processing Record 67 | Bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=bethel
# Processing Record 68 | Pahrump
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=pahrump
# Processing Record 69 | Duldurga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=duldurga
# Processing Record 70 | Nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=nanortalik
# Processing Record 71 | Darhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=darhan
# Processing Record 72 | Zunyi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=zunyi
# City not found. Skipping...
# Processing Record 73 | Aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=aklavik
# City not found. Skipping...
# Processing Record 74 | Saint George
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=saint george
# Processing Record 75 | Lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=lompoc
# Processing Record 76 | Coronel Bogado
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=coronel bogado
# Processing Record 77 | Talara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=talara
# Processing Record 78 | Peniche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=peniche
# Processing Record 79 | Moerai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=moerai
# Processing Record 80 | Amazar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=amazar
# Processing Record 81 | Tiarei
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=tiarei
# Processing Record 82 | Kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=kavaratti
# Processing Record 83 | Butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=butaritari
# Processing Record 84 | Pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=pevek
# Processing Record 85 | Concarneau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=concarneau
# Processing Record 86 | Necochea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=necochea
# Processing Record 87 | Kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=kapaa
# Processing Record 88 | Sola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=sola
# Processing Record 89 | Bowmore
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=bowmore
# Processing Record 90 | Guangyuan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=guangyuan
# Processing Record 91 | Kaeo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=kaeo
# Processing Record 92 | Robstown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=robstown
# City not found. Skipping...
# Processing Record 93 | Machico
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=machico
# Processing Record 94 | Yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=yellowknife
# Processing Record 95 | Kongolo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=kongolo
# City not found. Skipping...
# Processing Record 96 | Aranos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=aranos
# Processing Record 97 | Georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=georgetown
# Processing Record 98 | Grand Gaube
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=grand gaube
# Processing Record 99 | Sao Filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=sao filipe
# Processing Record 100 | Zhaotong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=zhaotong
# Processing Record 101 | Cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=cidreira
# Processing Record 102 | Puerto Ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=puerto ayora
# Processing Record 103 | Fatezh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=fatezh
# Processing Record 104 | Tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=tiksi
# Processing Record 105 | Middelburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=middelburg
# Processing Record 106 | Fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=fortuna
# Processing Record 107 | Saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=saskylakh
# Processing Record 108 | Christchurch
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=christchurch
# Processing Record 109 | East London
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=east london
# City not found. Skipping...
# Processing Record 110 | Dyurtyuli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=dyurtyuli
# Processing Record 111 | Mar del Plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=mar del plata
# Processing Record 112 | Narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=narsaq
# Processing Record 113 | Zhaozhou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=zhaozhou
# Processing Record 114 | Narasannapeta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=narasannapeta
# Processing Record 115 | Alugan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=alugan
# City not found. Skipping...
# Processing Record 116 | Yumen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=yumen
# Processing Record 117 | Kropotkin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=kropotkin
# Processing Record 118 | Tremedal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=tremedal
# Processing Record 119 | Okhotsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=okhotsk
# City not found. Skipping...
# Processing Record 120 | Moron
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=moron
# City not found. Skipping...
# Processing Record 121 | Mandera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=mandera
# Processing Record 122 | Quelimane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=quelimane
# Processing Record 123 | Castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=castro
# Processing Record 124 | Otradnoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=otradnoye
# Processing Record 125 | Karratha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=karratha
# Processing Record 126 | Najran
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=najran
# Processing Record 127 | General Roca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=general roca
# Processing Record 128 | Aykhal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=aykhal
# Processing Record 129 | Kununurra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=kununurra
# Processing Record 130 | Umm Lajj
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=umm lajj
# Processing Record 131 | Baie-Comeau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=baie-comeau
# Processing Record 132 | Kloulklubed
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=kloulklubed
# Processing Record 133 | Porto Novo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=porto novo
# Processing Record 134 | Cabo San Lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=cabo san lucas
# Processing Record 135 | Terrace
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=terrace
# Processing Record 136 | Itarema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=itarema
# Processing Record 137 | Chicama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=chicama
# Processing Record 138 | Ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=ahipara
# Processing Record 139 | Vila Velha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=vila velha
# Processing Record 140 | Juarez
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=juarez
# Processing Record 141 | Mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=mahebourg
# Processing Record 142 | Saint-Philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=saint-philippe
# Processing Record 143 | Nemuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=nemuro
# Processing Record 144 | Batemans Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=batemans bay
# City not found. Skipping...
# Processing Record 145 | Port Elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=port elizabeth
# Processing Record 146 | Hadishahr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=hadishahr
# Processing Record 147 | Atar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=atar
# Processing Record 148 | Hambantota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=hambantota
# Processing Record 149 | Sao Joao da Barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=sao joao da barra
# Processing Record 150 | Meadow Lake
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=meadow lake
# Processing Record 151 | Sapatgram
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=sapatgram
# Processing Record 152 | Pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=pangnirtung
# Processing Record 153 | Brainerd
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=brainerd
# Processing Record 154 | Chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=chokurdakh
# Processing Record 155 | Troitsko-Pechorsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=troitsko-pechorsk
# Processing Record 156 | Makakilo City
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=makakilo city
# Processing Record 157 | Suntar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=suntar
# Processing Record 158 | Kirakira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=kirakira
# Processing Record 159 | Muros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=muros
# Processing Record 160 | Iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=iqaluit
# Processing Record 161 | Mayumba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=mayumba
# Processing Record 162 | Filadelfia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=filadelfia
# City not found. Skipping...
# Processing Record 163 | Buala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=buala
# Processing Record 164 | Itoman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=itoman
# City not found. Skipping...
# Processing Record 165 | Horsham
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=horsham
# Processing Record 166 | Ihosy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=ihosy
# Processing Record 167 | Jinji
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=jinji
# Processing Record 168 | Dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=dikson
# Processing Record 169 | Guymon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=guymon
# Processing Record 170 | Walvis Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=walvis bay
# City not found. Skipping...
# Processing Record 171 | Richards Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=richards bay
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 172 | Denpasar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=denpasar
# Processing Record 173 | Hualmay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=hualmay
# Processing Record 174 | Nalut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=nalut
# Processing Record 175 | Ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=ancud
# Processing Record 176 | Hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=hasaki
# Processing Record 177 | Aguilas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=aguilas
# Processing Record 178 | Banda Aceh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=banda aceh
# City not found. Skipping...
# Processing Record 179 | Freeport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=freeport
# Processing Record 180 | Longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=longyearbyen
# Processing Record 181 | Manono
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=manono
# Processing Record 182 | Lafiagi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=lafiagi
# Processing Record 183 | Fairbanks
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=fairbanks
# Processing Record 184 | Comodoro Rivadavia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=comodoro rivadavia
# Processing Record 185 | Puri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=puri
# Processing Record 186 | Port Lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=port lincoln
# Processing Record 187 | Los Llanos de Aridane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=los llanos de aridane
# City not found. Skipping...
# Processing Record 188 | Hirara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=hirara
# Processing Record 189 | Rio Gallegos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=rio gallegos
# Processing Record 190 | Iracoubo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=iracoubo
# Processing Record 191 | Merrill
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=merrill
# Processing Record 192 | Puksoozero
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=puksoozero
# Processing Record 193 | Verkhnevilyuysk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=verkhnevilyuysk
# Processing Record 194 | Dongsheng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=dongsheng
# Processing Record 195 | Laguna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=laguna
# Processing Record 196 | Nouadhibou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=nouadhibou
# Processing Record 197 | Vao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=vao
# Processing Record 198 | Rajula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=rajula
# Processing Record 199 | Katrineholm
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=katrineholm
# Processing Record 200 | Bintulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=bintulu
# Processing Record 201 | Alice Springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=alice springs
# Processing Record 202 | Isangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=isangel
# City not found. Skipping...
# Processing Record 203 | Maceio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=maceio
# Processing Record 204 | Bubaque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=bubaque
# Processing Record 205 | Mount Isa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=mount isa
# Processing Record 206 | Aquiraz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=aquiraz
# Processing Record 207 | Faya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=faya
# Processing Record 208 | Tsabong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=tsabong
# Processing Record 209 | Port Augusta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=port augusta
# Processing Record 210 | Calvinia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=calvinia
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 211 | Siilinjarvi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=siilinjarvi
# Processing Record 212 | Qaqortoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=qaqortoq
# Processing Record 213 | Namibe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=namibe
# Processing Record 214 | Labuhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=labuhan
# Processing Record 215 | Tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=tuktoyaktuk
# City not found. Skipping...
# Processing Record 216 | Guerrero Negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=guerrero negro
# Processing Record 217 | Carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=carnarvon
# City not found. Skipping...
# Processing Record 218 | Cordoba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=cordoba
# Processing Record 219 | Arraial do Cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=arraial do cabo
# City not found. Skipping...
# Processing Record 220 | Komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=komsomolskiy
# Processing Record 221 | Were Ilu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=were ilu
# Processing Record 222 | Hamilton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=hamilton
# Processing Record 223 | Ballina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=ballina
# Processing Record 224 | Solwezi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=solwezi
# Processing Record 225 | Lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=lorengau
# Processing Record 226 | Lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=lebu
# City not found. Skipping...
# Processing Record 227 | Half Moon Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=half moon bay
# Processing Record 228 | Saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=saldanha
# Processing Record 229 | Corinto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=corinto
# Processing Record 230 | Den Helder
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=den helder
# Processing Record 231 | Aloleng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=aloleng
# Processing Record 232 | Avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=avarua
# Processing Record 233 | Manokwari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=manokwari
# Processing Record 234 | Ulladulla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=ulladulla
# Processing Record 235 | Marsa Matruh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=marsa matruh
# Processing Record 236 | Mehamn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=mehamn
# Processing Record 237 | Igarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=igarka
# Processing Record 238 | Sahuaripa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=sahuaripa
# Processing Record 239 | Mayo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=mayo
# Processing Record 240 | Carberry
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=carberry
# Processing Record 241 | Baker City
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=baker city
# Processing Record 242 | Northam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=northam
# Processing Record 243 | Tahe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=tahe
# City not found. Skipping...
# Processing Record 244 | Pocone
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=pocone
# City not found. Skipping...
# Processing Record 245 | Bambous Virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=bambous virieux
# Processing Record 246 | Karpogory
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=karpogory
# Processing Record 247 | Nyurba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=nyurba
# Processing Record 248 | Remanso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=remanso
# Processing Record 249 | Qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=qaanaaq
# Processing Record 250 | Saint-Leu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=saint-leu
# City not found. Skipping...
# Processing Record 251 | Lebanon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=lebanon
# City not found. Skipping...
# Processing Record 252 | Pindiga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=pindiga
# Processing Record 253 | Iquique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=iquique
# Processing Record 254 | Tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=tasiilaq
# Processing Record 255 | Pamekasan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=pamekasan
# Processing Record 256 | Karsava
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=karsava
# Processing Record 257 | Praia da Vitoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=praia da vitoria
# Processing Record 258 | Agadez
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=agadez
# Processing Record 259 | Delfzijl
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=delfzijl
# Processing Record 260 | Synya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=synya
# Processing Record 261 | Kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=kavieng
# Processing Record 262 | Cortez
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=cortez
# Processing Record 263 | Mizdah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=mizdah
# Processing Record 264 | Shakawe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=shakawe
# Processing Record 265 | Bang Saphan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=bang saphan
# Processing Record 266 | Barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=barrow
# Processing Record 267 | Faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=faanui
# Processing Record 268 | Ibra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=ibra
# Processing Record 269 | Esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=esperance
# Processing Record 270 | Gisenyi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=gisenyi
# Processing Record 271 | Alyangula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=alyangula
# Processing Record 272 | Emirdag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=emirdag
# Processing Record 273 | Chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=chuy
# Processing Record 274 | Fort Nelson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=fort nelson
# City not found. Skipping...
# Processing Record 275 | Pochutla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=pochutla
# Processing Record 276 | Kisangani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=kisangani
# Processing Record 277 | North Bend
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=north bend
# Processing Record 278 | Yerbogachen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=yerbogachen
# City not found. Skipping...
# Processing Record 279 | Lang Son
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=lang son
# Processing Record 280 | College
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=college
# Processing Record 281 | Lazaro Cardenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=lazaro cardenas
# Processing Record 282 | Blue Springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=blue springs
# Processing Record 283 | Katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=katsuura
# Processing Record 284 | Itaituba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=itaituba
# Processing Record 285 | Panjab
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=panjab
# City not found. Skipping...
# Processing Record 286 | Torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=torbay
# Processing Record 287 | Sindor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=sindor
# Processing Record 288 | Elbistan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=elbistan
# Processing Record 289 | Taunggyi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=taunggyi
# Processing Record 290 | Ponta do Sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=ponta do sol
# Processing Record 291 | Thunder Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=thunder bay
# Processing Record 292 | Ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=ilulissat
# Processing Record 293 | Littlehampton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=littlehampton
# Processing Record 294 | Noumea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=noumea
# Processing Record 295 | Ati
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=ati
# City not found. Skipping...
# Processing Record 296 | Obo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=obo
# Processing Record 297 | Cassilandia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=cassilandia
# Processing Record 298 | Kodinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=kodinsk
# City not found. Skipping...
# Processing Record 299 | Roros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=roros
# Processing Record 300 | Tabas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=tabas
# Processing Record 301 | Mananjary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=mananjary
# Processing Record 302 | Leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=leningradskiy
# Processing Record 303 | Unai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=unai
# Processing Record 304 | Caravelas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=caravelas
# Processing Record 305 | Uspenka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=uspenka
# Processing Record 306 | Manado
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=manado
# Processing Record 307 | Talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=talnakh
# Processing Record 308 | Broken Hill
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=broken hill
# Processing Record 309 | Saint-Pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=saint-pierre
# Processing Record 310 | Qasigiannguit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=qasigiannguit
# City not found. Skipping...
# Processing Record 311 | San Jeronimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=san jeronimo
# Processing Record 312 | Luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=luderitz
# Processing Record 313 | San Matias
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=san matias
# Processing Record 314 | Lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=lincoln
# Processing Record 315 | Saint-Joseph
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=saint-joseph
# Processing Record 316 | Lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=lagoa
# Processing Record 317 | Sayanogorsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=sayanogorsk
# Processing Record 318 | Nortelandia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=nortelandia
# Processing Record 319 | Shingu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=shingu
# Processing Record 320 | Campos Gerais
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=campos gerais
# Processing Record 321 | Sterling
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=sterling
# Processing Record 322 | Saint-Georges
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=saint-georges
# ...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=tanete
# Processing Record 427 | Broome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=broome
# Processing Record 428 | Nizhniy Kuranakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=nizhniy kuranakh
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 429 | Bonavista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=bonavista
# Processing Record 430 | Port Blair
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=port blair
# Processing Record 431 | Miramar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=miramar
# Processing Record 432 | Banjarmasin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=banjarmasin
# Processing Record 433 | Kurumkan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=kurumkan
# City not found. Skipping...
# Processing Record 434 | Conceicao do Araguaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=conceicao do araguaia
# Processing Record 435 | Poum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=poum
# Processing Record 436 | Kesztolc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=kesztolc
# City not found. Skipping...
# Processing Record 437 | Ust-Ilimsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=ust-ilimsk
# Processing Record 438 | Chateau-Gontier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=chateau-gontier
# Processing Record 439 | Cayenne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=cayenne
# Processing Record 440 | Pampa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=pampa
# Processing Record 441 | Abha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=abha
# City not found. Skipping...
# Processing Record 442 | Alcaniz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=alcaniz
# Processing Record 443 | Bambanglipuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=bambanglipuro
# Processing Record 444 | Bedele
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=bedele
# Processing Record 445 | Cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=cherskiy
# City not found. Skipping...
# Processing Record 446 | Barinas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=barinas
# Processing Record 447 | Bratsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=bratsk
# Processing Record 448 | Zhengjiatun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=zhengjiatun
# Processing Record 449 | Balaipungut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=balaipungut
# Processing Record 450 | Longyan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=longyan
# Processing Record 451 | Semnan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=semnan
# Processing Record 452 | Naryan-Mar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=naryan-mar
# Processing Record 453 | Tura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=tura
# Processing Record 454 | Caidian
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=caidian
# Processing Record 455 | Rumford
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=rumford
# Processing Record 456 | Constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=constitucion
# Processing Record 457 | Bireun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=bireun
# Processing Record 458 | Sydney
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=sydney
# Processing Record 459 | Palmas Bellas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=palmas bellas
# Processing Record 460 | Belaya Gora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=belaya gora
# Processing Record 461 | Lumajang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=lumajang
# Processing Record 462 | Ouargaye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=ouargaye
# Processing Record 463 | Muzhi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=muzhi
# Processing Record 464 | Hobyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=hobyo
# Processing Record 465 | Moche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=moche
# Processing Record 466 | Miguel Calmon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=miguel calmon
# Processing Record 467 | Bollnas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=bollnas
# Processing Record 468 | Nizhnevartovsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=nizhnevartovsk
# Processing Record 469 | Ornskoldsvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=ornskoldsvik
# City not found. Skipping...
# Processing Record 470 | Rawson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=rawson
# City not found. Skipping...
# Processing Record 471 | Kijang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=kijang
# Processing Record 472 | Srandakan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=srandakan
# Processing Record 473 | Mayachnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=mayachnyy
# Processing Record 474 | Adra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=adra
# City not found. Skipping...
# Processing Record 475 | Hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=hofn
# Processing Record 476 | Acapulco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=acapulco
# Processing Record 477 | Faro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=faro
# Processing Record 478 | Bayir
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=bayir
# Processing Record 479 | Hudiksvall
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=hudiksvall
# Processing Record 480 | Lugovoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=lugovoy
# Processing Record 481 | Aguimes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=aguimes
# Processing Record 482 | Madurai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=madurai
# Processing Record 483 | Harlingen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=harlingen
# Processing Record 484 | Tucupita
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=tucupita
# Processing Record 485 | Simpang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=simpang
# Processing Record 486 | Olinda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=olinda
# City not found. Skipping...
# Processing Record 487 | Taoudenni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=taoudenni
# Processing Record 488 | Rio Grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=rio grande
# Processing Record 489 | Three Hills
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=three hills
# Processing Record 490 | Murgab
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=murgab
# Processing Record 491 | Beyneu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=beyneu
# Processing Record 492 | Apricena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=apricena
# Processing Record 493 | Khorinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=khorinsk
# Processing Record 494 | Lusambo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=lusambo
# Processing Record 495 | Flin Flon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=flin flon
# Processing Record 496 | Isla Vista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=isla vista
# Processing Record 497 | Ler
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=ler
# Processing Record 498 | Axim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=axim
# Processing Record 499 | Babstovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=babstovo
# Processing Record 500 | Demba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=demba
# Processing Record 501 | Sunrise Manor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=sunrise manor
# Processing Record 502 | Kumluca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=kumluca
# Processing Record 503 | Inta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=inta
# Processing Record 504 | Kilemary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=kilemary
# Processing Record 505 | Mozarlandia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=mozarlandia
# Processing Record 506 | Stranda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=stranda
# Processing Record 507 | Boaco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=boaco
# Processing Record 508 | Fare
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=fare
# Processing Record 509 | Matamoros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=matamoros
# City not found. Skipping...
# Processing Record 510 | Meulaboh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=meulaboh
# Processing Record 511 | Hay River
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=hay river
# Processing Record 512 | Virginia Beach
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=virginia beach
# City not found. Skipping...
# Processing Record 513 | Kiri Buru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=kiri buru
# Processing Record 514 | Anadyr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=anadyr
# Processing Record 515 | Yaring
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=yaring
# City not found. Skipping...
# Processing Record 516 | Santa Isabel do Rio Negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=santa isabel do rio negro
# City not found. Skipping...
# Processing Record 517 | Linxia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=linxia
# Processing Record 518 | Along
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=along
# Processing Record 519 | Sioux Lookout
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=sioux lookout
# Processing Record 520 | Sedan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=sedan
# Processing Record 521 | Veraval
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=veraval
# Processing Record 522 | Namatanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=namatanai
# Processing Record 523 | Carutapera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=carutapera
# Processing Record 524 | Kichera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=kichera
# Processing Record 525 | Dedougou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=dedougou
# Processing Record 526 | Upata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=upata
# Processing Record 527 | Constantine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=constantine
# Processing Record 528 | Presidencia Roque Saenz Pena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=presidencia roque saenz pena
# Processing Record 529 | Egvekinot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=egvekinot
# Processing Record 530 | Suda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=suda
# Processing Record 531 | Baiyin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=baiyin
# City not found. Skipping...
# Processing Record 532 | San Andres
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83c5226a926768528805b1c3d0415a8d&q=san andres

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a dictonary with the lists generated
weatherpy_dict = {
    "City": city_name,
    "Cloudiness":cloudiness,
    "Country":country,
    "Date":date,
    "Humidity": humidity,
    "Lat":lat,
    "Lng":lng,
    "Max Temp": max_temp,
    "Wind Speed":wind_speed
}
# Create a data frame from dictionary
weather_data = pd.DataFrame(weatherpy_dict)
# Display count of weather data values
weather_data.count()
# Out:
# City          532
# Cloudiness    532
# Country       532
# Date          532
# Humidity      532
# Lat           532
# Lng           532
# Max Temp      532
# Wind Speed    532
# dtype: int64

# %%
# Save data frame to CSV
weather_data.to_csv("output_data_cities.csv")

# Display data frame head
weather_data.head()
# Out:
#                   City  Cloudiness Country        Date  Humidity    Lat  \
# 0              Mataura         100      NZ  1566702497        96 -46.19
# 1              Karibib           0      NA  1566702498        23 -21.94
# 2                Vaini          40      IN  1566702499        94  15.34
# 3            Jamestown          90      AU  1566702356        58 -33.21
# 4  San Miguel de Cauri         100      PE  1566702502        97 -10.10
#
#       Lng  Max Temp  Wind Speed
# 0  168.86     48.00        4.00
# 1   15.86     56.55        8.10
# 2   74.49     69.80        6.93
# 3  138.60     49.51        7.43
# 4  -76.58     33.99        3.20

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature") 
plt.ylabel("Max. Temperature (F)") 
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Output_Plots_Max_Temp_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity") 
plt.ylabel("Humidity (%)") 
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Output_Plots_Humidity_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness") 
plt.ylabel("Cloudiness (%)") 
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Output_Plots_Cloudiness_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed") 
plt.ylabel("Wind Speed (mph)") 
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Output_Plots_Wind_Speed_vs_Latitude.png")

#Show plot
plt.show()
